# %%
Using Plotly express as px, source the data using the command px.data.gapminder() and save it
into a dataframe. Based on the data, map the following information with the appropriate
geographical plot. Map out:
1. The mean life expectancy of all the Asian countries according to the data.
2. Deviation in GDP of each country in Europe and South America.
3. The change in population of each African country in the last 3 decades

# %%
import pandas as pd
import plotly.express as px
df = px.data.gapminder()
import numpy as np

# %%
import plotly.express as px
px.data.gapminder()
# Out:
#           country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
# ...           ...       ...   ...      ...       ...         ...       ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 0           4
# 1           4
# 2           4
# ...

# %%
df = px.data.gapminder()
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
#  6   iso_alpha  1704 non-null   object
#  7   iso_num    1704 non-null   int64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 106.6+ KB

# %%
df.describe()
# Out:
#              year      lifeExp           pop      gdpPercap      iso_num
# count  1704.00000  1704.000000  1.704000e+03    1704.000000  1704.000000
# mean   1979.50000    59.474439  2.960121e+07    7215.327081   425.880282
# std      17.26533    12.917107  1.061579e+08    9857.454543   248.305709
# min    1952.00000    23.599000  6.001100e+04     241.165877     4.000000
# 25%    1965.75000    48.198000  2.793664e+06    1202.060309   208.000000
# 50%    1979.50000    60.712500  7.023596e+06    3531.846989   410.000000
# 75%    1993.25000    70.845500  1.958522e+07    9325.462346   638.000000
# max    2007.00000    82.603000  1.318683e+09  113523.132900   894.000000

# %%
df = px.data.gapminder()
print(df.dtypes)
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# iso_alpha     object
# iso_num        int64
# dtype: object

# %%
df = px.data.gapminder()
grouped_continent_df = df.groupby('continent') 
print(type(grouped_continent_df))
# Out:
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>

# %%
print(grouped_continent_df)

# %%
grouped_continent_df_lifeExp = grouped_continent_df['lifeExp'] 
print(type(grouped_continent_df_lifeExp))
# Out:
# <class 'pandas.core.groupby.generic.SeriesGroupBy'>

# %%
q.1The mean life expectancy of all the Asian countries according to the data.

# %%
mean_lifeExp_by_continent = grouped_continent_df_lifeExp.mean() 
print(mean_lifeExp_by_continent)
# Out:
# continent
# Africa      48.865330
# Americas    64.658737
# Asia        60.064903
# Europe      71.903686
# Oceania     74.326208
# Name: lifeExp, dtype: float64

# %%
mean=Asia =60.064903

# %%
import plotly.express as px
df = px.data.gapminder()
gfig = px.scatter_mapbox(df, lat="year", lon="pop", hover_name="country", hover_data=["continent", "lifeExp"],
                        color_discrete_sequence=["fuchsia"], zoom=3, height=300)
fig.update_layout(mapbox_style="carto-positron")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <div>                            <div id="f0870e8a-80b3-4753-9646-fafa8b4a3195" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f0870e8a-80b3-4753-9646-fafa8b4a3195")) {                    Plotly.newPlot(                        "f0870e8a-80b3-4753-9646-fafa8b4a3195",                        [{"customdata": [["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Europe", "Albania"], ["Europe", "Albania"], ["Europe", "Albania"], ["Europe", "Albania"], ["Europe", "Albania"], ["Europe", "Albania"], ["Europe", "A
# ...

# %%
q.2 Deviation in GDP of each country in Europe and South America.

# %%
mycolumns = ['country','gdpPercap'] 

df[mycolumns]
# Out:
#           country   gdpPercap
# 0     Afghanistan  779.445314
# 1     Afghanistan  820.853030
# 2     Afghanistan  853.100710
# 3     Afghanistan  836.197138
# 4     Afghanistan  739.981106
# ...           ...         ...
# 1699     Zimbabwe  706.157306
# 1700     Zimbabwe  693.420786
# 1701     Zimbabwe  792.449960
# 1702     Zimbabwe  672.038623
# 1703     Zimbabwe  469.709298
#
# [1704 rows x 2 columns]

# %%
df.std()
# Out:
# year         1.726533e+01
# lifeExp      1.291711e+01
# pop          1.061579e+08
# gdpPercap    9.857455e+03
# iso_num      2.483057e+02
# dtype: float64

# %%
import plotly.express as px
df = px.data.gapminder()
gfig = px.scatter_mapbox(df, lat="year", lon="pop", hover_name="country", hover_data=["continent", "gdpPercap"],
                        color_discrete_sequence=["fuchsia"], zoom=3, height=300)
fig.update_layout(mapbox_style="carto-positron")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <div>                            <div id="d25adb49-a6a2-42a7-b831-7fc89b1aee33" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d25adb49-a6a2-42a7-b831-7fc89b1aee33")) {                    Plotly.newPlot(                        "d25adb49-a6a2-42a7-b831-7fc89b1aee33",                        [{"customdata": [["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Europe", "Albania"], ["Europe", "Albania"], ["Europe", "Albania"], ["Europe", "Albania"], ["Europe", "Albania"], ["Europe", "Albania"], ["Europe", "A
# ...

# %%
q.3 The change in population of each African country in the last 3 decades

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4

# %%
df = px.data.gapminder()
print(df.tail(n=7))
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 1697  Zimbabwe    Africa  1977   57.674   6642107  685.587682       ZWE
# 1698  Zimbabwe    Africa  1982   60.363   7636524  788.855041       ZWE
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306       ZWE
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786       ZWE
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960       ZWE
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623       ZWE
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298       ZWE
#
#       iso_num
# 1697      716
# 1698      716
# 1699      716
# 1700      716
# 1701      716
# 1702      716
# 1703      716

# %%
df = px.data.gapminder()

import plotly.express as px

import pandas as pd


df= px.data.gapminder
import plotly.express as px

import pandas as pd

# %%
import plotly.express as px
df = px.data.gapminder()


import plotly.express as px
df = px.data.gapminder()
gfig = px.scatter_mapbox(df, lat="year", lon="pop", hover_name="country", hover_data=["continent", "pop"],
                        color_discrete_sequence=["fuchsia"], zoom=3, height=300)
fig.update_layout(mapbox_style="carto-positron")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <div>                            <div id="fb92ba20-8f83-4570-883f-5bc43103ac86" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb92ba20-8f83-4570-883f-5bc43103ac86")) {                    Plotly.newPlot(                        "fb92ba20-8f83-4570-883f-5bc43103ac86",                        [{"customdata": [["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Asia", "Afghanistan"], ["Europe", "Albania"], ["Europe", "Albania"], ["Europe", "Albania"], ["Europe", "Albania"], ["Europe", "Albania"], ["Europe", "Albania"], ["Europe", "A
# ...
