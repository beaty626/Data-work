# %%
import pandas as pd 

import plotly.graph_objs as go

telcom = pd.read_csv(r'C:\Users\User\Desktop\Telco_Churn.csv')

print (telcom)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
telcom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
telcom.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
1. Demographic:
a. Which 2 demographics have proven to be the most popular with the telco brand?
b. If the marketing team wanted to ,increase customer retention to whom should
they target their advertisements to?

# %%
telcom.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
1. a) 2 demographics have proven to be the most popular with the telco brand basing on the Maximum values areTenure and Monthlycharges.

# %%
telcom.iloc[0:7043, 1:5]
# Out:
#       gender  SeniorCitizen Partner Dependents
# 0     Female              0     Yes         No
# 1       Male              0      No         No
# 2       Male              0      No         No
# 3       Male              0      No         No
# 4     Female              0      No         No
# ...      ...            ...     ...        ...
# 7038    Male              0     Yes        Yes
# 7039  Female              0     Yes        Yes
# 7040  Female              0     Yes        Yes
# 7041    Male              1     Yes         No
# 7042    Male              0      No         No
#
# [7043 rows x 4 columns]

# %%
telcom.plot(x='MonthlyCharges', y = 'tenure')
# Out:
# <AxesSubplot:xlabel='MonthlyCharges'>

# %%
1. b) If the marketing team wanted to ,increase customer retention to whom should
they target their advertisements to?

# %%
telcom[["MonthlyCharges", "TotalCharges","Churn"]]
# Out:
#       MonthlyCharges TotalCharges Churn
# 0              29.85        29.85    No
# 1              56.95       1889.5    No
# 2              53.85       108.15   Yes
# 3              42.30      1840.75    No
# 4              70.70       151.65   Yes
# ...              ...          ...   ...
# 7038           84.80       1990.5    No
# 7039          103.20       7362.9    No
# 7040           29.60       346.45    No
# 7041           74.40        306.6   Yes
# 7042          105.65       6844.5    No
#
# [7043 rows x 3 columns]

# %%
They should target their advertisement on those with Yes in Churn column.

# %%
import seaborn as sns

sns.catplot(x="MonthlyCharges", y="Churn", hue="Churn", data=telcom)

# %%
2. Services:
a. Which 3 services are contributing to a higher monthly charge and resulting to
customers churning? (Use visualizations in explaining your analysis)
b. If the telco was to offer Phone as a standalone service, which type of contract
would encourage customer retention?

# %%
2. a) Which 3 services are contributing to a higher monthly charge and resulting to
customers churning? (Use visualizations in explaining your analysis)



Paperless billing
Phone servicing
Online security

# %%
mycolumns = ['PaperlessBilling','PhoneService', 'OnlineSecurity'] 
telcom[mycolumns]
# Out:
#      PaperlessBilling PhoneService OnlineSecurity
# 0                 Yes           No             No
# 1                  No          Yes            Yes
# 2                 Yes          Yes            Yes
# 3                  No           No            Yes
# 4                 Yes          Yes             No
# ...               ...          ...            ...
# 7038              Yes          Yes            Yes
# 7039              Yes          Yes             No
# 7040              Yes           No            Yes
# 7041              Yes          Yes             No
# 7042              Yes          Yes            Yes
#
# [7043 rows x 3 columns]

# %%
import seaborn as sns
g = sns.relplot(x="PaperlessBilling", y="PhoneService", hue="OnlineSecurity", data=telcom ,col="Churn")

# %%
2. b) If the telco was to offer Phone as a standalone service, which type of contract
would encourage customer retention?


Month-to-month contract

# %%
3. Payment: (Use visualizations in explaining your analysis)
a. If the company was to streamline all its services into 3 bouquet packages, what
monthly prices will be appropriate for the following packages to keep customers
from churning:
i. Basic
ii. Plus
iii. Premium

# %%
mycolumns = ['MonthlyCharges', 'PhoneService', 'InternetService', 'MultipleLines','OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies','Churn'] 
telcom[mycolumns]
# Out:
#       MonthlyCharges PhoneService InternetService     MultipleLines  \
# 0              29.85           No             DSL  No phone service
# 1              56.95          Yes             DSL                No
# 2              53.85          Yes             DSL                No
# 3              42.30           No             DSL  No phone service
# 4              70.70          Yes     Fiber optic                No
# ...              ...          ...             ...               ...
# 7038           84.80          Yes             DSL               Yes
# 7039          103.20          Yes     Fiber optic               Yes
# 7040           29.60           No             DSL  No phone service
# 7041           74.40          Yes     Fiber optic               Yes
# 7042          105.65          Yes     Fiber optic                No
#
#      OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0                No          Yes               No          No          No
# ...

# %%
3. b) Should the company strictly go paperless for their monthly billings as a technique
of keeping their customers and why?

# %%
mycolumns = ['PaperlessBilling','MonthlyCharges', 'Churn'] 
telcom[mycolumns]
# Out:
#      PaperlessBilling  MonthlyCharges Churn
# 0                 Yes           29.85    No
# 1                  No           56.95    No
# 2                 Yes           53.85   Yes
# 3                  No           42.30    No
# 4                 Yes           70.70   Yes
# ...               ...             ...   ...
# 7038              Yes           84.80    No
# 7039              Yes          103.20    No
# 7040              Yes           29.60    No
# 7041              Yes           74.40   Yes
# 7042              Yes          105.65    No
#
# [7043 rows x 3 columns]

# %%
import seaborn as sns
g = sns.relplot(x="MonthlyCharges", y="PaperlessBilling", hue="Churn", data=telcom ,col="Churn")

# %%
No, it has high rates of churning.
